# %%
#exercicio 01
print("Eu estou aprendendo python")
# Out:
# Eu estou aprendendo python

# %%
#exercicio 02
nome= "Bruna"
cidade= "Goiânia"
print ("Meu nome é" , nome)
print ("Eu moro em", cidade)
# Out:
# Meu nome é Bruna
# Eu moro em Goiânia

# %%
#exercicio 03
nome_aluno= "Ana"
idade_do_aluno= 18
print("Meu nome é", nome_aluno, "e tenho",idade_do_aluno,"anos")
# Out:
# Meu nome é Ana e tenho 18 anos

# %%
#exercicio 04
cidade= "Goiânia"
estado= "Goiás"
pais= "Brasil"
print("Eu moro em "+ cidade+" - " +estado +", "+ pais+".")
# Out:
# Eu moro em Goiânia - Goiás, Brasil.
